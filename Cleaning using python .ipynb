# %%
import pandas as pd  
import numpy as np

# %%
df = pd.read_csv("D:\DataSets\Airbnb\Airbnb_Open_Data.csv")
df.head()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_33952\706297213.py:1: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("D:\DataSets\Airbnb\Airbnb_Open_Data.csv")
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# ...

# %%
# to get the shape of the data set
df.shape
# Out:
# (102599, 26)

# %%
df.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='object')

# %%
# to get the information of the data set
df.info(verbose =True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              102599 non-null  int64
#  1   NAME                            102349 non-null  object
#  2   host id                         102599 non-null  int64
#  3   host_identity_verified          102310 non-null  object
#  4   host name                       102193 non-null  object
#  5   neighbourhood group             102570 non-null  object
#  6   neighbourhood                   102583 non-null  object
#  7   lat                             102591 non-null  float64
#  8   long                            102591 non-null  float64
#  9   country                         102067 non-null  object
#  10  country code                    102468 non-null  object
#  11  instant_bookable                102494 non-null  object
# ...

# %%
# Drop columns that are not required for analysis 
columns_to_drop =[
    'id',
    'reviews per month',
    'license',
    'availability 365',
    'house_rules',
    'calculated host listings count',
    'review rate number'
    ]

columns_to_keep =[col for col in df.columns if col not in columns_to_drop]

# %%
print("Number of Columns to Keep =>",len(columns_to_keep))
print("Number of Columns to drop =>",len(columns_to_drop))
# Out:
# Number of Columns to Keep => 19
# Number of Columns to drop => 7

# %% [markdown]
# # Dropping Columns

# %% [markdown]
# - 1nd method Dropping & Filtering Data

# %%
# Data = df[columns_to_keep]
# Data.shape

# %% [markdown]
# - 2nd method Dropping Columns

# %%
df.drop(columns=columns_to_drop,inplace=True)

# %%
df.shape
# Out:
# (102599, 19)

# %% [markdown]
# # Renaming the columns

# %%
# to get the information of the data set
df.columns
# Out:
# Index(['NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review'],
#       dtype='object')

# %% [markdown]
# - 1nd method to rename columns

# %%
#df.rename(columns={'NAME':'Name','host id':'HostID',},inplace=True)

# %% [markdown]
# - 2nd method to rename columns

# %%
new_columns = []
for i in df.columns: 
    new_columns.append(i.replace(" ","_").capitalize())

df.columns = new_columns
print(df.columns)
# Out:
# Index(['Name', 'Host_id', 'Host_identity_verified', 'Host_name',
#        'Neighbourhood_group', 'Neighbourhood', 'Lat', 'Long', 'Country',
#        'Country_code', 'Instant_bookable', 'Cancellation_policy', 'Room_type',
#        'Construction_year', 'Price', 'Service_fee', 'Minimum_nights',
#        'Number_of_reviews', 'Last_review'],
#       dtype='object')

# %% [markdown]
# # Check Duplication values

# %%
# df.duplicated()
# df.duplicated().values_counts()
# df.duplicated().head()
# df.duplicated().tail()
#df.duplicated().sum()
# df.drop_duplicates(inplace=True)
# df=df.drop_duplicates()

# %%
# to get the information of the duplicates in the data set
print("Number of Duplicates in the Data Set =",df.duplicated().sum())
# Out:
# Number of Duplicates in the Data Set = 541

# %%
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Check Null Values

# %%
# to get the information of the missing values in the data set 
#df.isnull() ==> boolean values flase for not missing values and true for missing values
#df.isnull().sum() ==> number of missing values in each column
#df.isnull().sum().sum() ==> number of missing values in the data set
#df.isnull().any() ==> columns with missing values
#df.isnull().any(axis=1) ==> rows with missing values
#df.isnull().all() ==> columns with all missing values
#df.isnull().all(axis=1) ==> rows with all missing values
#df.dropna() ==> drop rows with missing values
#df.dropna(axis=1) ==> drop columns with missing values
#df.fillna() ==> fill missing values with a default value
#df.fillna(method='ffill') ==> fill missing values with the previous value
#df.fillna(method='bfill') ==> fill missing values with the next value
#df.fillna(df.mean()) ==> fill missing values with the mean of the column

# %%
df.isnull().sum()
# Out:
# Name                        250
# Host_id                       0
# Host_identity_verified      289
# Host_name                   404
# Neighbourhood_group          29
# Neighbourhood                16
# Lat                           8
# Long                          8
# Country                     532
# Country_code                131
# Instant_bookable            105
# Cancellation_policy          76
# Room_type                     0
# Construction_year           214
# Price                       247
# Service_fee                 273
# Minimum_nights              400
# Number_of_reviews           183
# Last_review               15832
# dtype: int64

# %%
# missing_percentage = round((df.isnull().sum() / len(df)) * 100 ,2)  # Multiply by 100 once
# # missing_percentage = missing_percentage.sort_values(ascending=False)  # Uncomment if sorting is needed
# missing_percentage = missing_percentage.apply(lambda x: f"{x:.2f}%")
# print(missing_percentage)

# %%
# drop columns with more than 50% missing values 
df.drop(columns=['Last_review'],inplace=True)

# %%
# drop rows with missing values
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Name                      0
# Host_id                   0
# Host_identity_verified    0
# Host_name                 0
# Neighbourhood_group       0
# Neighbourhood             0
# Lat                       0
# Long                      0
# Country                   0
# Country_code              0
# Instant_bookable          0
# Cancellation_policy       0
# Room_type                 0
# Construction_year         0
# Price                     0
# Service_fee               0
# Minimum_nights            0
# Number_of_reviews         0
# dtype: int64

# %% [markdown]
# # Cleaning individual columns

# %%
# Cleaning Column 'Host_identity_verified' 
print(df['Host_identity_verified'].unique())
print(df['Host_identity_verified'].value_counts())
df['Host_identity_verified']=df['Host_identity_verified'].apply(lambda x : x .strip().capitalize())
df
# Out:
# ['unconfirmed' 'verified']
# Host_identity_verified
# unconfirmed    49707
# verified       49635
# Name: count, dtype: int64
#                                                     Name      Host_id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5              Large Cozy 1 BR Apartment In Midtown East  45498551794
# 7                                        BlissArtsSpace!  90821839709
# ...                                                  ...          ...
# 102029            Cozy room in a 2B with backyard access   5155155913
# 102030                      An East Williamsburg Delight  71564706996
# 102031                      Cozy bedroom in williamsburg  83101851929
# 102032                            Spacious Room w/ 2 Bed  69037598918
# 102040                     Room in Queens, NY, near LGA.  56457739998
#
# ...

# %%
# Add new column near to Instant_bookable column
df.insert(
    df.columns.get_loc('Instant_bookable') + 1,  # Position next to 'Instant_bookable'
    'Binary_Instant_bookable',  
    df['Instant_bookable'].apply(lambda x: 1 if x == True else 0)  # Convert to binary
)

# %%
df.head()
# Out:
#                                                Name      Host_id  \
# 0                Clean & quiet apt home by the park  80014485718
# 1                             Skylit Midtown Castle  52335172823
# 4  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5         Large Cozy 1 BR Apartment In Midtown East  45498551794
# 7                                   BlissArtsSpace!  90821839709
#
#   Host_identity_verified Host_name Neighbourhood_group       Neighbourhood  \
# 0            Unconfirmed  Madaline            Brooklyn          Kensington
# 1               Verified     Jenna           Manhattan             Midtown
# 4               Verified    Lyndon           Manhattan         East Harlem
# 5               Verified  Michelle           Manhattan         Murray Hill
# 7            Unconfirmed      Emma            Brooklyn  Bedford-Stuyvesant
#
#         Lat      Long        Country Country_code Instant_bookable  \
# ...

# %% [markdown]
# # Reset Indcies of dataset

# %%
df.reset_index(inplace=True)

# %% [markdown]
# # check for some more Transformations .

# %%
# [ price column ]  is object type     ==> need to convert to int and  remove $ sign and remove sapces
df['Price'].dtype
df['Price']=df['Price'].str.replace('$','').str.replace(',','').astype(int)

# %%
# [service fee]  is object type     ==> need cleaning to float and  remove $ sign
print(df['Price'].head())
# Out:
# 0     966
# 1     142
# 2     204
# 3     577
# 4    1060
# Name: Price, dtype: int32

# %%
df['Service_fee']=df['Service_fee'].str.replace("$","").str.replace(",","").str.replace(" ","").astype(float)

# %%
print(df['Service_fee'].head())
# Out:
# 0    193.0
# 1     28.0
# 2     41.0
# 3    115.0
# 4    212.0
# Name: Service_fee, dtype: float64

# %% [markdown]
# # Saving Data after Cleaning

# %%
df.drop(columns=['index'],inplace=True) # drop index column

# %%
#Save the cleaned data to a new file without index column
#df.to_csv("cleaned_airbnb_data.csv", index=False)                      # as  csv file
df.to_excel("cleaned_airbnb_data.xlsx", index=False)                   # as  excel file

# %%
data=pd.read_excel("cleaned_airbnb_data.xlsx")
data.head()
# Out:
#                                                Name      Host_id  \
# 0                Clean & quiet apt home by the park  80014485718
# 1                             Skylit Midtown Castle  52335172823
# 2  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 3         Large Cozy 1 BR Apartment In Midtown East  45498551794
# 4                                   BlissArtsSpace!  90821839709
#
#   Host_identity_verified Host_name Neighbourhood_group       Neighbourhood  \
# 0            Unconfirmed  Madaline            Brooklyn          Kensington
# 1               Verified     Jenna           Manhattan             Midtown
# 2               Verified    Lyndon           Manhattan         East Harlem
# 3               Verified  Michelle           Manhattan         Murray Hill
# 4            Unconfirmed      Emma            Brooklyn  Bedford-Stuyvesant
#
#         Lat      Long        Country Country_code  Instant_bookable  \
# ...
